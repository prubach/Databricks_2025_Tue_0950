# %%
#dbutils.fs.cp("dbfs:/Volumes/workspace/default/mydata/flights.zip", "/Workspace/tmp/flights.zip")

# %%
# %sh
cd /Volumes/workspace/default/mydata/
#cd /tmp
unzip flights.zip

# %%
# File location and type
file_location = "/Volumes/workspace/default/mydata/flights.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)

# %%
temp_table_name = "flights"

#df.createOrReplaceTempView(temp_table_name)
df.write.saveAsTable('aerospace.flights')

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `flights`
