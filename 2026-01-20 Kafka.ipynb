# %%
# !pip install kafka-python

# %%
dbutils.library.restartPython()

# %%
# Pure Python implementation, spark is not used
# bin/kafka-console-producer.sh --broker-list sih-60.cent.uw.edu.pl:49092 --topic bigdata-test-25
from kafka import KafkaConsumer
import sys
import time

consumer = KafkaConsumer('bigdata-test-25', bootstrap_servers=['sih-60.cent.uw.edu.pl:49092'], group_id='my_consumer')

for message in consumer:
  print(message.value.decode('utf-8'))
  time.sleep(1)
